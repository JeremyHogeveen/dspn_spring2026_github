# %% [markdown]
# # Data Science in Psychology and Neuroscience
#
# ## Class info:
# * Week #3
# * Day: February 3, 2026
# * Time: 9:30—10:45 AM
# * Location: Logan Hall 125
# * <a href="https://forms.microsoft.com/r/26vAcJWrwH">Click here to submit your attendance for Week 3, Question 5!</a>
#
# ## Instructor info:
# * Dr. Jeremy Hogeveen
# * jhogeveen@unm.edu
# * Logan Hall 281 (Office Hours By Appointment)
#
# ## Syllabus:
# * <a href="https://www.dropbox.com/scl/fi/6fs6fi4kvkwtxn7j7x8ua/PSY450650_DSPN_Spring2026_Syllabus.pdf?rlkey=148e5t4ah8q2n1daclt7mp0h6&dl=0">Download here</a>
#
# ## Today's topics:
# * <a href="https://github.com/JeremyHogeveen/dspn_spring2026_github/blob/main/code/dspn_spring2026_week2_01272026.ipynb">Review / check-in</a>
# 1. Working in Jupyter
# 2. Start coding in Python
# 3. Assignment #1 Debrief

# %% [markdown]
# # Section 1: The Jupyter "Notebook"
#
# ## 1.1 Working in a Jupyter "Kernel"
#
# * When we launch _jupyter-lab_, we initiate a "kernel" for us to work in.
# * Kernels are a fancy name for a way that we can interact with our computer using a specific programming language.
#   * Jupyter or other IDEs (e.g. IPython) help us interface for an underlying code "interpreter" that takes the instructions we give it and spits out the appropriate data / figure object / etc.
#   * Should be "Idle" when you are not running anything.
#   * Do not run anything while the kernel is working (i.e., will say "Python (dspn_env) | "Busy").
#   * If it seems frozen (not "Busy" but also not allowing you to type anything), try "Restart the kernel" option above.
#   * When we are done working, after saving our work, select "File-->Shut Down" to close the kernel and free up your command prompt.
#   * Kernels can be used for many different languages, most often it is used for Python, but in the future we will set up an R Kernel as well.
#
# ## 1.2 Jupyter cells
#
# * Markdown (what this section is)
#   * A _way_ to __specify__ all ___formatting___ within the text itself
# * Code (cell where you run actual Python code)
# * The primary hot keys for __running__ a cell in Jupyter Notebook and JupyterLab are Shift + Enter and Ctrl + Enter on Windows (or Cmd + Return on Mac).
#
# ## Markdown Formatting Tips

# %% [markdown]
# ### Header Levels...
# #### specified
# ##### using the pound sign.
#
# * Can do bulleted lists using asterisks:
#     * tabbing to indent subsequent levels
#
#   1. Numbered lists
#   2. number, period, space then your entry
#       1. designate subpoints by tabbing +restarting your number lists
#       2. lets see if this works.
#
# Here is a <a href="https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed">cheatsheet</a> with a bunch of other Markdown formatting stuff.

# %% [markdown]
# # Section 2: Doing some coding in Python
#
# ## 2.1 Writing Python code in Jupyter
#
# * Python is an __object-oriented__ programming language
#   * The things you create and/or read into Python are invariably some kind of __object__
# * Python objects can be, ___variables___

# %%
variable = 12
print('your first variable equals:',variable)
# Out:
# your first variable equals: 12

# %% [markdown]
# * Variables are most often __integers, floats, or strings__

# %%
floating_point_numbers = 3.14
integer = 3
string = 'pi'
print(string,'is equal too:',floating_point_numbers,'which is approximately',integer)
# Out:
# pi is equal too: 3.14 which is approximately 3

# %% [markdown]
# * Multiple variables can be assigned at once in Python

# %%
multiple, thing, line = floating_point_numbers, integer, string
print(string)
# Out:
# pi

# %% [markdown]
# * Mathematical operators can be applied to numerical variables
#   * Order of operations follows B() E** D/ M* A+ S-

# %%
variable_2 = 14
math_answer = (variable_2 - variable)**2 / 30
print('your first mathematical solution is:',math_answer)
# Out:
# your first mathematical solution is: 0.13333333333333333

# %% [markdown]
# * Division gives a few other options...
#   * if you want the closest integer, and it's remainder you can do...

# %%
math_answer_2 = (variable_2 - variable)**2 // 30
remainder = (variable_2 - variable)**2 % 30
print('the closest integer would be:',math_answer_2,', and its remainder is,',remainder)
# Out:
# the closest integer would be: 0 , and its remainder is, 4

# %% [markdown]
# * Python objects might also be collections (e.g. data frames and lists)

# %%
list_1 = [-96,-66,87,86,-88,-25,24,59,-99,59]
print('here is our first list:',list_1)
# Out:
# here is our first list: [-96, -66, 87, 86, -88, -25, 24, 59, -99, 59]

# %% [markdown]
# * Python objects might also be plots
#   * Won't get into this yet...

# %% [markdown]
# * With that in mind, lets write a code that can print "Hello World"

# %%
variable_3 = "hello"
variable_4 = "world"
print(variable_3,variable_4)
# Out:
# hello world

# %% [markdown]
# ### Packages, sub-packages, and modules
#
# * A ton of __packages__ have been developed
#     * Some of them general purpose (e.g. Numpy, Pandas)
#     * Some of them psych / neuro specific (e.g. psychopy, pygaze, MNE, Nipype, Brian, SPySort, etc etc etc)
# * Those packages contain "sub-packages" which do a set of related things
# * There are then individual "modules" or "functions" that do the stuff we want to do in Python
#
# <img src="img/package_module.png" width="450">
#
# ### E.g. use numpy to generate random list of integers between 0 and 100

# %%
import numpy as np
# from numpy import random as nprd

list_2 = np.random.randint(0,100,size=10)
# list_2 = nprd.randint(0,100,size=10)

print('Random integer list:',list_2)
# Out:
# Random integer list: [67 29  5 19 22 56 39 55  7  5]

# %%
# np.random?
# np.random.randint?

# %% [markdown]
# # Section 3: Assignment 1 Debrief
#
# * <a href="https://github.com/JeremyHogeveen/dspn_spring2026_github/tree/main/assignment_materials/Assignment_1">Here is a link to the assignment materials.</a>

# %%
# loading required libraries
import  sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Answering parts 1-5
print("I am ready to data science")
print("My Python version is:",sys.version_info)
print("My Numpy version is:",np.__version__)
print("My Pandas version is:",pd.__version__)
print("My current working directory is:",os.getcwd())

# Answering part 6
if os.path.exists('../data'):
    print("SUCCESS: 'data' folder found in the correct relative path!")
elif os.path.exists('data'):
    print("WARNING: 'data' folder is in the same directory, not standard, but acceptable.")
else:
    print("ERROR: Could not find the 'data' folder. Check your directory structure.")
# Out:
# I am ready to data science
# My Python version is: sys.version_info(major=3, minor=10, micro=19, releaselevel='final', serial=0)
# My Numpy version is: 2.2.6
# My Pandas version is: 2.3.3
# My current working directory is: /Users/jeremyhogeveen/Dropbox/Winter_2026/teaching/DSPN_Spring_2026/github/code
# SUCCESS: 'data' folder found in the correct relative path!
