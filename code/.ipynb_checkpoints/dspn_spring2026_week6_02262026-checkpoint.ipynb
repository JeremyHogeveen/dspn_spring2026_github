# %% [markdown]
# # Data Science in Psychology and Neuroscience
#
# ## Class info:
# * Week #6
# * Day: February 26, 2026
# * Time: 9:30—10:45 AM
# * Location: Zoom (asynchronous recording)
# * <a href="https://forms.microsoft.com/r/26vAcJWrwH">Click here to submit your attendance for Week 6, Question 12!</a>
#
# ## Instructor info:
# * Dr. Jeremy Hogeveen
# * jhogeveen@unm.edu
# * Logan Hall 281 (Office Hours By Appointment)
#
# ## Syllabus:
# * <a href="https://www.dropbox.com/scl/fi/6fs6fi4kvkwtxn7j7x8ua/PSY450650_DSPN_Spring2026_Syllabus.pdf?rlkey=148e5t4ah8q2n1daclt7mp0h6&dl=0">Download here</a>
#
# ## Today's topic:
# * Overview of ABCD Study wrangling (Assignment #3).
#
# ### What is the ABCD Study?
#
# <img src="img/abcdlogo500.jpg" width=300>
#
# * For Assignment #3, you will use the ABCD study data and the Pandas Python package that I introduced you to in our previous lectures to answer the following questions:
#
#     * 1. Across the full dataset, how many male and female subjects have complete data sets if I want to look at both i) household income from the demographics sheet, and ii) internalizing scores from the CBCL sheet.
#       2.  Across the full dataset, in the `pdem02` file, what is the minimum, maximum, mean, and standard deviation of interview_age at the baseline visit?
#       3.  Across the full dataset, what is the average reaction time (rt) for each of the columns in the `abcd_mid02` file?
#       4.  Across the full dataset, create a wide dataframe of the `abcd_cbcls01` visit data, where each row is a subject and columns represent CBCL Attention scores (cbcl_scr_syn_attention_t) at Baseline vs. 6-Month Follow-up. Create a variable for the difference score between cbcl_scr_syn_attention_t at each time point. How many subjects showed an increase of 5 points or more in their attention score over that time period?
#       5.  Filtering to just the subjects in the `subjectkeys.txt` file, create a mega data frame containing all the data across all questionnaires for only this subgroup of participants.
#
# * Each item will be worth 2 points, with 1 point for showing some effort and 1 point for generating the correct answer. A starter code to help you get started on this assignment is provided in the <a href="https://github.com/JeremyHogeveen/dspn_spring2026_github/tree/main/assignment_materials">assignment_materials</a> subfolder if you need to use it!.
