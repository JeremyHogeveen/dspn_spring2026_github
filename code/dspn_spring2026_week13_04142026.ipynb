# %% [markdown]
# # Data Science in Psychology and Neuroscience
#
# ## Class info:
# * Week #13
# * Day: April 14, 2026
# * Time: 9:30—10:45 AM
# * Location: Logan Hall 125
# * <a href="https://forms.microsoft.com/r/26vAcJWrwH">Click here to submit your attendance for Question 23!</a>
#
# ## Instructor info:
# * Dr. Jeremy Hogeveen
# * jhogeveen@unm.edu
# * Logan Hall 281 (Office Hours By Appointment)
#
# ## Syllabus:
# * <a href="https://www.dropbox.com/scl/fi/6fs6fi4kvkwtxn7j7x8ua/PSY450650_DSPN_Spring2026_Syllabus.pdf?rlkey=148e5t4ah8q2n1daclt7mp0h6&dl=0">Download here</a>
#
# ## Today:
#
# * Final assignment
#     * What it is
#     * Goal
#     * Suggestions
#     * "So... what do I actually submit?"
#     * Evaluation
# * Example project I worked on...
#
# ## Homework
# * Modeling Assignment #5:
#     * Due by 04/15/2026, 11:00 MT. <a href="https://www.dropbox.com/request/u9g0AKjkTjjwVzptaZJY">Submission link</a>
# * Final Assignment:
#     * Presentation dates:
#         * 04/30
#         * 05/05
#         * 05/07
#     * Written component:
#         * Due 05/08/2026, 11:00 MT. <a href="https://www.dropbox.com/request/T9S6sM7gxBzypqUbzcUM">Submission link</a>

# %% [markdown]
# # Final assignment
#
# ## What is the assignment?
# * Think of a data science-y thing you could not do before this course.
#     * "What is data science again?"
#
# <img src="img/what_is_ds.png">
#
# * Do the thing, then tell me what you did (and how you did it).
#
# ## Goal
# * In research training, you frequently have to learn new skills on top of managing existing projects.
#     * Often, totally unclear whether those skills are _definitely_ going to lead to a real research "product."
#     * My goal: Give you a space to tackle such a challenge with the guarantee of benefitting through course credit.
#
# ## Suggestions for content and scope:
# 1. Will it benefit your future research?
#     * If unlikely, back to the drawing board.
# 2. Is it feasible?
#     * If not, is there a smaller component you can take on?
# 3. Is it a challenge?
#     * If not, can you expand on it to make it a challenge?
#
# <img src="img/grogu_reach.gif">
#
# ## "What do I submit?"
# 1. A presentation.
#     * ≈10-15 mins.
# 2. Any supplementary materials that are relevant to understanding #1.
#     * Code, figures, etc.
#
# ## How will I evaluate it
# * 80% Effort.
#     * Based on the assignments so far, I have a good idea for individual levels of data science expertise.
#     * If the assignment clearly exemplifies that you have pushed yourself to advance your training, you'll get full marks here.
# * 20% Presentation quality.
#     * Communication is a key component of a (data) scientist's toolkit.
#     * If you clearly lay out...
#         * Relevant background
#         * Specific skill you learned
#         * What / how you learned
#     * ...then you will also get full marks here.

# %% [markdown]
# # Example project:
#
# * Transcranial Magnetic Information:
#     * Modeling trial-by-trial motor-evoked potential amplitude as a function of surprise (Hogeveen, $c.2013$, _the file drawer_)
#     * A young me's ≈40 minute research talk on this "Transcranial_Magnetic_Information.pptx"
